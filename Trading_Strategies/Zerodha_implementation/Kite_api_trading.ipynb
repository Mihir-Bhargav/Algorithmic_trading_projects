# %%
import logging
from kiteconnect import KiteConnect 
logging.basicConfig(level=logging.DEBUG)

kite = KiteConnect(api_key="p6vzf3je78hvp6l1")
kite.login_url()
# Out:
# 'https://kite.zerodha.com/connect/login?api_key=p6vzf3je78hvp6l1&v=3'

# %%
data = kite.generate_session("dngP8pVmBv6hClH80x2orF3vDt7HWPe4", api_secret="7ddoafhnna3xvstatr1e50w8bqgs0twb")
kite.set_access_token(data["access_token"])
kite.holdings() 
# Have to do this every 24 hours
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade:443
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /session/token HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /portfolio/holdings HTTP/1.1" 200 30
# []

# %%
kite.holdings()
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /portfolio/holdings HTTP/1.1" 200 30
# []

# %%
kite.profile()
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /user/profile HTTP/1.1" 200 None
# {'user_id': 'UB8181',
#  'user_type': 'individual/res_no_nn',
#  'email': 'prabhat.ramesh@gmail.com',
#  'user_name': 'Prabhat Nallamad Ramesh',
#  'user_shortname': 'Prabhat',
#  'broker': 'ZERODHA',
#  'exchanges': ['NFO', 'BFO', 'BCD', 'NSE', 'BSE', 'MF'],
#  'products': ['CNC', 'NRML', 'MIS', 'BO', 'CO'],
#  'order_types': ['MARKET', 'LIMIT', 'SL', 'SL-M'],
#  'avatar_url': None,
#  'meta': {'demat_consent': 'consent'}}

# %%
values = []
for x in range(-5,10):
    y = 3 * x**2 + -14 * x + 1
    values.append(y)

print(max(values))
print(min(values))
import matplotlib.pyplot as plt
plt.plot(values)
plt.show()
# Out:
# 146
# -15

# %%
from breeze_connect import BreezeConnect

# Initialize SDK
breeze = BreezeConnect(api_key="your_api_key")

# Obtain your session key from https://api.icicidirect.com/apiuser/login?api_key=YOUR_API_KEY
# Incase your api-key has special characters(like +,=,!) then encode the api key before using in the url as shown below.
import urllib
print("https://api.icicidirect.com/apiuser/login?api_key="+urllib.parse.quote_plus("your_api_key"))

# Generate Session
breeze.generate_session(api_secret="your_secret_key",
                        session_token="your_api_session")

# Generate ISO8601 Date/DateTime String
import datetime
iso_date_string = datetime.datetime.strptime("28/02/2021","%d/%m/%Y").isoformat()[:10] + 'T05:30:00.000Z'
iso_date_time_string = datetime.datetime.strptime("28/02/2021 23:59:59","%d/%m/%Y %H:%M:%S").isoformat()[:19] + '.000Z'
# Out:
# https://api.icicidirect.com/apiuser/login?api_key=your_api_key
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.icicidirect.com:443
# DEBUG:urllib3.connectionpool:https://api.icicidirect.com:443 "GET /breezeapi/api/v1/customerdetails HTTP/1.1" 200 64
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\breeze_connect\breeze_connect.py:840, in BreezeConnect.api_util(self)
#     839 elif json_data['Error'] == 'Public Key does not exist.':
# --> 840     raise Exception(except_message.APPKEY_INCORRECT.value)
#     841 elif json_data['Error'] == 'Resource not available.':
#
# Exception: Could not authenticate credentials. Please check api key.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[27], line 12
#       9 print("https://api.icicidirect.com/apiuser/login?api_key="+urllib.parse.quote_plus("your_api_key"))
#      11 # Generate Session
# ---> 12 breeze.generate_session(api_secret="your_secret_key",
#      13                         session_token="your_api_session")
#      15 # Generate ISO8601 Date/DateTime String
#      16 import datetime
#
# File ~\AppData\Roaming\Python\Python313\site-packages\breeze_connect\breeze_connect.py:891, in BreezeConnect.generate_session(self, api_secret, session_token)
#     889 self.session_key = session_token
#     890 self.secret_key = api_secret
# --> 891 self.api_util()
#     892 self.get_stock_script_list()
#     893 self.api_handler = ApificationBreeze(self)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\breeze_connect\breeze_connect.py:855, in BreezeConnect.api_util(self)
#     852     raise Exception(f"KeyError: {e} not found in API response")
#     853 except Exception as e:
#     854     # Handle other exceptions
# --> 855     raise Exception(f"Unexpected error: {str(e)}")
#
# Exception: Unexpected error: Could not authenticate credentials. Please check api key.

# %%
# Fetch Historical Data
breeze.get_historical_data(interval="1minute",
                  from_date= "2025-02-03T09:20:00.000Z",
                  to_date= "2025-02-03T09:22:00.000Z",
                  stock_code="NIFTY",
                  exchange_code="NFO",
                  product_type="options",
                  expiry_date="2025-02-06T07:00:00.000Z",
                  right="call",
                  strike_price="23200")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 breeze.get_historical_data(interval="1minute",
#       2                   from_date= "2025-02-03T09:20:00.000Z",
#       3                   to_date= "2025-02-03T09:22:00.000Z",
#       4                   stock_code="NIFTY",
#       5                   exchange_code="NFO",
#       6                   product_type="options",
#       7                   expiry_date="2025-02-06T07:00:00.000Z",
#       8                   right="call",
#       9                   strike_price="23200")
#
# NameError: name 'breeze' is not defined
