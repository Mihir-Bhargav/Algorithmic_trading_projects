# %% [markdown]
# # Real-time Implementation and Automation with IBKR

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# _Disclaimer: <br>
# The following illustrative examples are for general information and educational purposes only. <br>
# It is neither investment advice nor a recommendation to trade, invest or take whatsoever actions.<br>
# The below code should only be used in combination with an IBKR Practice/Demo Account and NOT with a Live Trading Account._

# %% [markdown]
# ------------------------------------------------------------------------------------

# %% [markdown]
# ## IBKR API - Recap

# %% [markdown]
# __Update__: ib_insync has been migrated to __ib_async__. From now on, __please use ib_async:__

# %% [markdown]
# pip install ib_async

# %%
from ib_async import *
util.startLoop()

# %%
ib = IB()

# %%
ib.connect()
# Out:
# Error 326, reqId -1: Unable to connect as the client id is already in use. Retry with a unique client id.
# Peer closed connection. clientId 1 already in use?
# API connection failed: TimeoutError()
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File c:\Users\mihir\anaconda3\Lib\asyncio\tasks.py:507, in wait_for(fut, timeout)
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File c:\Users\mihir\anaconda3\Lib\asyncio\futures.py:286, in Future.__await__(self)
#     285     self._asyncio_future_blocking = True
# --> 286     yield self  # This tells Task to wait for completion.
#     287 if not self.done():
#
# File c:\Users\mihir\anaconda3\Lib\asyncio\tasks.py:375, in Task.__wakeup(self, future)
#     374 try:
# --> 375     future.result()
#     376 except BaseException as exc:
#     377     # This may also be a cancellation.
#
# File c:\Users\mihir\anaconda3\Lib\asyncio\futures.py:194, in Future.result(self)
#     193 if self._state == _CANCELLED:
# --> 194     raise self._make_cancelled_error()
#     195 if self._state != _FINISHED:
#
# CancelledError:
#
# The above exception was the direct cause of the following exception:
#
# TimeoutError                              Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ib.connect()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ib_async\ib.py:369, in IB.connect(self, host, port, clientId, timeout, readonly, account, raiseSyncErrors, fetchFields)
#     329 def connect(
#     330     self,
#     331     host: str = "127.0.0.1",
#    (...)    338     fetchFields: StartupFetch = StartupFetchALL,
#     339 ):
#     340     """
#     341     Connect to a running TWS or IB gateway application.
#     342     After the connection is made the client is fully synchronized
#    (...)    367           to the ``fetchFields`` parameter as needed.
#     368     """
# --> 369     return self._run(
#     370         self.connectAsync(
#     371             host,
#     372             port,
#     373             clientId,
#     374             timeout,
#     375             readonly,
#     376             account,
#     377             raiseSyncErrors,
#     378             fetchFields,
#     379         )
#     380     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ib_async\ib.py:428, in IB._run(self, *awaitables)
#     427 def _run(self, *awaitables: Awaitable):
# --> 428     return util.run(*awaitables, timeout=self.RequestTimeout)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ib_async\util.py:374, in run(timeout, *awaitables)
#     372 globalErrorEvent.connect(onError)
#     373 try:
# --> 374     result = loop.run_until_complete(task)
#     375 except asyncio.CancelledError as e:
#     376     raise globalErrorEvent.value() or e
#
# File ~\AppData\Roaming\Python\Python313\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File c:\Users\mihir\anaconda3\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File c:\Users\mihir\anaconda3\Lib\asyncio\tasks.py:306, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     304         result = coro.send(None)
#     305     else:
# --> 306         result = coro.throw(exc)
#     307 except StopIteration as exc:
#     308     if self._must_cancel:
#     309         # Task is cancelled right before coro stops.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ib_async\ib.py:2043, in IB.connectAsync(self, host, port, clientId, timeout, readonly, account, raiseSyncErrors, fetchFields)
#    2040 timeout = timeout or None
#    2041 try:
#    2042     # establish API connection
# -> 2043     await self.client.connectAsync(host, port, clientId, timeout)
#    2045     # autobind manual orders
#    2046     if clientId == 0:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ib_async\client.py:228, in Client.connectAsync(self, host, port, clientId, timeout)
#     219     msg = b"API\0" + self._prefix(
#     220         b"v%d..%d%s"
#     221         % (
#    (...)    225         )
#     226     )
#     227     self.conn.sendMsg(msg)
# --> 228     await asyncio.wait_for(self.apiStart, timeout)
#     229     self._logger.info("API connection ready")
#     230 except BaseException as e:
#
# File c:\Users\mihir\anaconda3\Lib\asyncio\tasks.py:506, in wait_for(fut, timeout)
#     503     except exceptions.CancelledError as exc:
#     504         raise TimeoutError from exc
# --> 506 async with timeouts.timeout(timeout):
#     507     return await fut
#
# File c:\Users\mihir\anaconda3\Lib\asyncio\timeouts.py:116, in Timeout.__aexit__(self, exc_type, exc_val, exc_tb)
#     112 if self._task.uncancel() <= self._cancelling and exc_type is not None:
#     113     # Since there are no new cancel requests, we're
#     114     # handling this.
#     115     if issubclass(exc_type, exceptions.CancelledError):
# --> 116         raise TimeoutError from exc_val
#     117     elif exc_val is not None:
#     118         self._insert_timeout_error(exc_val)
#
# TimeoutError:

# %%
ib.positions()
# Out:
# []

# %%
contract = Forex('EURUSD')
contract
# Out:
# Forex('EURUSD', exchange='IDEALPRO')

# %%
ib.qualifyContracts(contract)
# Out:
# [Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD')]

# %%
data = ib.reqMktData(contract) # subscribe to tick data
data
# Out:
# Ticker(contract=Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD'), defaults=IBDefaults(emptyPrice=-1, emptySize=0, unset=nan, timezone=datetime.timezone.utc), created=True)

# %%
data
# Out:
# Ticker(contract=Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD'), defaults=IBDefaults(emptyPrice=-1, emptySize=0, unset=nan, timezone=datetime.timezone.utc), created=True)

# %%
data.bid
# Out:
# nan

# %%
ib.cancelMktData(contract) # unsubscribe market data
# Out:
# True

# %%
ib.reqMktData(contract)
# Out:
# Ticker(contract=Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD'), time=datetime.datetime(2026, 2, 11, 19, 25, 22, 540522, tzinfo=datetime.timezone.utc), timestamp=1770837922.5405278, minTick=1e-05, bid=1.18839, bidSize=2500000.0, ask=1.18843, askSize=7500000.0, last=1.1884, lastSize=0.0, lastTimestamp=datetime.datetime(2026, 2, 11, 19, 25, 17, tzinfo=datetime.timezone.utc), volume=0.0, high=1.1927, low=1.18335, close=1.1895, ticks=[TickData(time=datetime.datetime(2026, 2, 11, 19, 25, 22, 540522, tzinfo=datetime.timezone.utc), tickType=1, price=1.18839, size=2500000.0), TickData(time=datetime.datetime(2026, 2, 11, 19, 25, 22, 540522, tzinfo=datetime.timezone.utc), tickType=2, price=1.18843, size=7500000.0)], defaults=IBDefaults(emptyPrice=-1, emptySize=0, unset=nan, timezone=datetime.timezone.utc), created=True)

# %%
ticker = ib.ticker(contract)
ticker
# Out:
# Ticker(contract=Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD'), defaults=IBDefaults(emptyPrice=-1, emptySize=0, unset=nan, timezone=datetime.timezone.utc), created=True)

# %%
ticker.bid
# Out:
# nan

# %%
ib.cancelMktData(contract) # unsubscribe market data
# Out:
# cancelMktData: No reqId found for contract Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD')
# False

# %%
ib.disconnect()

# %% [markdown]
# ## Streaming Tick Data

# %%
from ib_async import *
import pandas as pd
util.startLoop() 
ib = IB()

# %%
ib.connect()
# Out:
# <IB connected to 127.0.0.1:7497 clientId=1>
# Error 10197, reqId 36: No market data during competing live session, contract: Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD')
# Error 10197, reqId 36: No market data during competing live session, contract: Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD')
# Error 10197, reqId 36: No market data during competing live session, contract: Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD')

# %%
contract = Forex('EURUSD')
ib.qualifyContracts(contract)  # populate conId so the contract can be hashed
ib.reqMktData(contract)
ticker = ib.ticker(contract)

# %%
ticker
# Out:
# Ticker(contract=Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD'), defaults=IBDefaults(emptyPrice=-1, emptySize=0, unset=nan, timezone=datetime.timezone.utc), created=True)

# %%
def onPendingTickers(tickers): # what shall happen after receiving a new tick
    global message
    message = "time: {} | Bid: {} | Ask:{}".format(ticker.time, ticker.bid, ticker.ask)
    print(message, end = '\r')

# %%
ib.pendingTickersEvent += onPendingTickers # activate onPendingTickers
ib.sleep(30) # new, to be added!!!
# Out:
# True

# %%
# Print the latest message if it exists, otherwise print a notice
try:
	print(message)  # still getting updated
except NameError:
	print("No tick data received yet. 'message' is not defined.")
# Out:
# No tick data received yet. 'message' is not defined.

# %%
ib.pendingTickersEvent -= onPendingTickers # de-activate onPendingTickers

# %%
ticker
# Out:
# Ticker(contract=Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD'), defaults=IBDefaults(emptyPrice=-1, emptySize=0, unset=nan, timezone=datetime.timezone.utc), created=True)

# %%
ib.cancelMktData(contract)
# Out:
# True

# %%
ib.disconnect()
# Out:
# 'Disconnecting from 127.0.0.1:7497, 380 B sent in 13 messages, 22.8 kB received in 456 messages, session time 425 s.'

# %% [markdown]
# ## Streaming Tick Data for multiple Symbols

# %%
from ib_async import *
import pandas as pd
from IPython.display import display, clear_output
util.startLoop() 
ib = IB()

# %%
ib.connect()
# Out:
# <IB connected to 127.0.0.1:7497 clientId=1>
# Error 10197, reqId 42: No market data during competing live session, contract: Forex('AUDUSD', conId=14433401, exchange='IDEALPRO', localSymbol='AUD.USD', tradingClass='AUD.USD')
# Error 10197, reqId 40: No market data during competing live session, contract: Forex('USDCHF', conId=12087820, exchange='IDEALPRO', localSymbol='USD.CHF', tradingClass='USD.CHF')
# Error 10197, reqId 39: No market data during competing live session, contract: Forex('GBPUSD', conId=12087797, exchange='IDEALPRO', localSymbol='GBP.USD', tradingClass='GBP.USD')
# Error 10197, reqId 41: No market data during competing live session, contract: Forex('USDCAD', conId=15016062, exchange='IDEALPRO', localSymbol='USD.CAD', tradingClass='USD.CAD')
# Error 10197, reqId 37: No market data during competing live session, contract: Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD')
# Error 10197, reqId 38: No market data during competing live session, contract: Forex('USDJPY', conId=15016059, exchange='IDEALPRO', localSymbol='USD.JPY', tradingClass='USD.JPY')
# Peer closed connection.

# %%
contracts = [Forex(pair) for pair in ('EURUSD', 'USDJPY', 'GBPUSD', 'USDCHF', 'USDCAD', 'AUDUSD')]
ib.qualifyContracts(*contracts)
# Out:
# [Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD'),
#  Forex('USDJPY', conId=15016059, exchange='IDEALPRO', localSymbol='USD.JPY', tradingClass='USD.JPY'),
#  Forex('GBPUSD', conId=12087797, exchange='IDEALPRO', localSymbol='GBP.USD', tradingClass='GBP.USD'),
#  Forex('USDCHF', conId=12087820, exchange='IDEALPRO', localSymbol='USD.CHF', tradingClass='USD.CHF'),
#  Forex('USDCAD', conId=15016062, exchange='IDEALPRO', localSymbol='USD.CAD', tradingClass='USD.CAD'),
#  Forex('AUDUSD', conId=14433401, exchange='IDEALPRO', localSymbol='AUD.USD', tradingClass='AUD.USD')]

# %%
for contract in contracts:
    ib.reqMktData(contract)

# %%
df = pd.DataFrame(
    index=[c.pair() for c in contracts],
    columns=['bidSize', 'bid', 'ask', 'askSize', 'high', 'low', 'close'])
df
# Out:
#        bidSize  bid  ask askSize high  low close
# EURUSD     NaN  NaN  NaN     NaN  NaN  NaN   NaN
# USDJPY     NaN  NaN  NaN     NaN  NaN  NaN   NaN
# GBPUSD     NaN  NaN  NaN     NaN  NaN  NaN   NaN
# USDCHF     NaN  NaN  NaN     NaN  NaN  NaN   NaN
# USDCAD     NaN  NaN  NaN     NaN  NaN  NaN   NaN
# AUDUSD     NaN  NaN  NaN     NaN  NaN  NaN   NaN

# %%
def onPendingTickers(tickers): # what shall happen after receiving a new tick
    for t in tickers:
        df.loc[t.contract.pair()] = (
            t.bidSize, t.bid, t.ask, t.askSize, t.high, t.low, t.close)
        clear_output(wait=True)
    display(df)

# %%
ib.pendingTickersEvent += onPendingTickers # activate onPendingTickers
ib.sleep(30) # new to be added!!!
# Out:
# True

# %%
df # still getting updated
# Out:
#        bidSize  bid  ask askSize high  low close
# EURUSD     NaN  NaN  NaN     NaN  NaN  NaN   NaN
# USDJPY     NaN  NaN  NaN     NaN  NaN  NaN   NaN
# GBPUSD     NaN  NaN  NaN     NaN  NaN  NaN   NaN
# USDCHF     NaN  NaN  NaN     NaN  NaN  NaN   NaN
# USDCAD     NaN  NaN  NaN     NaN  NaN  NaN   NaN
# AUDUSD     NaN  NaN  NaN     NaN  NaN  NaN   NaN

# %%
ib.pendingTickersEvent -= onPendingTickers # de-activate onPendingTickers

# %%
for contract in contracts:
    ib.cancelMktData(contract)

# %%
ib.disconnect()

# %% [markdown]
# ## Streaming Real Time Bars (and Historical)

# %% [markdown]
# - Trading Stratgies use bar data (uniform time periods with ohlc data), not tick data (non-constant frequency, based on trades and quotes)
# - An SMA Crossover 50/200 (days) Strategy works with daily bars.
# - Day Trading Strategies are based on e.g. [1min, 5min, 20min, 1h, 3h, 6h] bars
# - Bar Size / Frequency itself is a Strategy Parameter (to be optimized)

# %%
from ib_async import *
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
util.startLoop()

# %%
ib = IB()
ib.connect()

# %%
contract = Forex('EURUSD')
contract

# %% [markdown]
# __durationStr__: Time span of all the bars. Examples:
#         __'60 S', '30 D', '13 W', '6 M', '10 Y'__.

# %% [markdown]
# __barSizeSetting__: Time period of one bar. Must be one of:
#         __'1 secs', '5 secs', '10 secs' 15 secs', '30 secs',
#         '1 min', '2 mins', '3 mins', '5 mins', '10 mins', '15 mins',
#         '20 mins', '30 mins',
#         '1 hour', '2 hours', '3 hours', '4 hours', '8 hours',
#         '1 day', '1 week', '1 month'__.

# %%
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='100 S',
        barSizeSetting='10 secs',
        whatToShow='MIDPOINT',
        useRTH=True,
        formatDate=2,
        keepUpToDate=True)

# %%
bars

# %%
pd.DataFrame(bars)

# %%
ib.cancelHistoricalData(bars) # cancel subscription

# %%
def onBarUpdate(bars, hasNewBar):  # what shall happen after receiving a new bar
    global df
    df = pd.DataFrame(bars)[["date", "open", "high", "low", "close"]]
    df.set_index("date", inplace = True)
    clear_output(wait=True)
    display(df)

# %%
# start stream
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='50 S',
        barSizeSetting='5 secs',
        whatToShow='MIDPOINT',
        useRTH=True,
        formatDate=2,
        keepUpToDate=True)

# %%
bars.updateEvent += onBarUpdate # activate onBarUpdate
ib.sleep(30) # new to be added!!!

# %%
df # still getting updated until you de-activate or cancel

# %%
bars.updateEvent -= onBarUpdate # de-activate onBarUpdate

# %%
ib.cancelHistoricalData(bars) # cancel subscription

# %% [markdown]
# ## Application: Creating a live Candle Stick Chart

# %%
def onBarUpdate(bars, hasNewBar):
    plt.close()
    plot = util.barplot(bars, title = "EURUSD", upColor = "green", downColor = "red")
    clear_output(wait=True)
    display(plot)

# %%
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='1000 S',
        barSizeSetting='10 secs',
        whatToShow='MIDPOINT',
        useRTH=True,
        formatDate=2,
        keepUpToDate=True)

# %%
bars.updateEvent += onBarUpdate # activate onBarUpdate
ib.sleep(30) # new to be added!!!

# %%
bars.updateEvent -= onBarUpdate # de-activate onBarUpdate

# %%
ib.cancelHistoricalData(bars) # cancel subscription

# %%
ib.disconnect()

# %% [markdown]
# ## Preparing the Data for Day Trading

# %% [markdown]
# - Problem: most recent bar is (typically) incomplete (until the end of the bar has been reached)
# - In Trading: Take actions once a new bar is complete

# %%
from ib_async import * 
import pandas as pd
import numpy as np
import datetime as dt # old
from datetime import datetime, timezone # new
from IPython.display import display, clear_output
util.startLoop()

# %%
ib = IB()
ib.connect()

# %%
contract = Forex('EURUSD')
contract

# %%
dt.datetime.utcnow() # old

# %%
datetime.now(timezone.utc) # new (Python 3.12)

# %%
def onBarUpdate(bars, hasNewBar):
    # print(dt.datetime.utcnow()) # old
    print(datetime.now(timezone.utc)) # new (Python 3.12)

# %%
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='1 D',
        barSizeSetting='1 min',
        whatToShow='MIDPOINT',
        useRTH=True,
        formatDate=2,
        keepUpToDate=True)

# %%
bars.updateEvent += onBarUpdate
ib.sleep(30) # new to be added!!!

# %%
ib.cancelHistoricalData(bars)

# %%
def onBarUpdate(bars, hasNewBar): 
    global df
    df = pd.DataFrame(bars)[["date", "open", "high", "low", "close"]].iloc[:-1] # remove current bar (incomplete)
    df.set_index("date", inplace = True)
    clear_output(wait=True)
    display(df)

# %%
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='1 D',
        barSizeSetting='1 min',
        whatToShow='MIDPOINT',
        useRTH=True,
        formatDate=2,
        keepUpToDate=True)
bars.updateEvent += onBarUpdate 
ib.sleep(90) # new to be added!!!

# %%
df # still getting updated until you cancel

# %%
ib.cancelHistoricalData(bars)

# %% [markdown]
# ## Improving Code Efficiency

# %% [markdown]
# Idea: We need to run major parts of onBarUpdate only if a bar is complete (== new bar has been added)

# %%
bars

# %%
# check if current (incomplete) bar is more recent than the last complete bar
bars[-1].date > bars[-2].date

# %%
def onBarUpdate(bars, hasNewBar):  
    global df, last_bar
    if bars[-1].date > last_bar: # if bar completed / new bar
        last_bar = bars[-1].date
    
        df = pd.DataFrame(bars)[["date", "open", "high", "low", "close"]].iloc[:-1] 
        df.set_index("date", inplace = True)
        clear_output(wait=True)
        display(df)

# %%
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='1 D',
        barSizeSetting='1 min',
        whatToShow='MIDPOINT',
        useRTH=True,
        formatDate=2,
        keepUpToDate=True)
last_bar = bars[-1].date # initialize last_bar
bars.updateEvent += onBarUpdate
ib.sleep(90) # new to be added!!!

# %%
df # still getting updated until you cancel

# %%
ib.cancelHistoricalData(bars)

# %%
ib.disconnect()

# %%
df

# %%
last_bar

# %% [markdown]
# ## Define an SMA Day Trading Strategy

# %%
from ib_async import * 
import pandas as pd
import numpy as np
#import datetime as dt
from IPython.display import display, clear_output
util.startLoop()

# %%
ib = IB()
ib.connect()

# %%
contract = Forex('EURUSD')
contract

# %% [markdown]
# Strategy: SMA 50/200 (minutes) Crossover (needs to be backtested!!!)

# %%
sma_s = 50
sma_l = 200

# %%
def onBarUpdate(bars, hasNewBar): 
    global df, last_bar
    
    if bars[-1].date > last_bar: 
        last_bar = bars[-1].date
    
        # Data Processing
        df = pd.DataFrame(bars)[["date", "open", "high", "low", "close"]].iloc[:-1]
        df.set_index("date", inplace = True)
        
        ####################### Trading Strategy ###########################
        df = df[["close"]].copy()
        df["sma_s"] = df.close.rolling(sma_s).mean()
        df["sma_l"] = df.close.rolling(sma_l).mean()
        df.dropna(inplace = True)
        df["position"] = np.where(df["sma_s"] > df["sma_l"], 1, -1 )
        ####################################################################
        
        # Action
        clear_output(wait=True)
        display(df)

# %%
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='1 D',
        barSizeSetting='1 min',
        whatToShow='MIDPOINT',
        useRTH=True,
        formatDate=2,
        keepUpToDate=True)
last_bar = bars[-1].date
bars.updateEvent += onBarUpdate 
ib.sleep(120) # new to be added!!!

# %%
df # still getting updated until you cancel

# %%
ib.cancelHistoricalData(bars)

# %%
ib.disconnect()

# %% [markdown]
# ## Trading

# %% [markdown]
# __Please run the following code only with your Paper Trading Account!!!__

# %% [markdown]
# __Check the Regular Trading Hours!!!__

# %%
from ib_async import * 
import pandas as pd
import numpy as np
#import datetime as dt
from IPython.display import display, clear_output
util.startLoop()

# %%
ib = IB()
ib.connect()

# %%
# strategy parameters
sma_s = 50
sma_l = 200
freq = "1 min"
units = 1000
contract = Forex('EURUSD') # for data streaming
ib.qualifyContracts(contract)
cfd = CFD("EUR", currency = "USD") # for trading
ib.qualifyContracts(cfd)
conID = cfd.conId

# %%
conID

# %% [markdown]
# __barSizeSetting__: Time period of one bar. Must be one of:
#         __'1 secs', '5 secs', '10 secs' 15 secs', '30 secs',
#         '1 min', '2 mins', '3 mins', '5 mins', '10 mins', '15 mins',
#         '20 mins', '30 mins',
#         '1 hour', '2 hours', '3 hours', '4 hours', '8 hours',
#         '1 day', '1 week', '1 month'__.

# %%
def onBarUpdate(bars, hasNewBar):  
    global df, last_bar
    
    if bars[-1].date > last_bar: 
        last_bar = bars[-1].date
    
        # Data Processing
        df = pd.DataFrame(bars)[["date", "open", "high", "low", "close"]].iloc[:-1] 
        df.set_index("date", inplace = True)
        
        ####################### Trading Strategy ###########################
        df = df[["close"]].copy()
        df["sma_s"] = df.close.rolling(sma_s).mean()
        df["sma_l"] = df.close.rolling(sma_l).mean()
        df.dropna(inplace = True)
        df["position"] = np.where(df["sma_s"] > df["sma_l"], 1, -1 )
        ####################################################################
        
        # Trading
        target = df["position"][-1] * units
        execute_trade(target = target)
        
        # Display
        clear_output(wait=True)
        display(df)
    else:
        pass

def execute_trade(target):
    global current_pos
    
    # 1. get current Position
    try:
        current_pos = [pos.position for pos in ib.positions() if pos.contract.conId == conID][0]
    except:
        current_pos = 0
         
    # 2. identify required trades
    trades = target - current_pos
        
    # 3. trade execution
    if trades > 0:
        side = "BUY"
        order = MarketOrder(side, abs(trades))
        trade = ib.placeOrder(cfd, order)  
    elif trades < 0:
        side = "SELL"
        order = MarketOrder(side, abs(trades))
        trade = ib.placeOrder(cfd, order)
    else:
        pass

# %%
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='1 D', # must be sufficiently long!!! (200 * 1 min)
        barSizeSetting=freq,
        whatToShow='MIDPOINT',
        useRTH=True,
        formatDate=2,
        keepUpToDate=True)
last_bar = bars[-1].date
bars.updateEvent += onBarUpdate
ib.sleep(240) # new - to be added

# %%
### remember: Trading continues until you cancel!!!

# %%
ib.cancelHistoricalData(bars)  # cancel trading

# %%
df

# %%
ib.disconnect()

# %% [markdown]
# ## Trade Reporting

# %%
from ib_async import * 
import pandas as pd
import numpy as np
#import datetime as dt
from datetime import datetime, timezone # new
from IPython.display import display, clear_output
util.startLoop()

# %%
ib = IB()
ib.connect()

# %%
ib.fills()

# %%
util.df([fs.execution for fs in ib.fills()])[["execId", "time", "side", "cumQty", "avgPrice"]].set_index("execId")

# %%
util.df([fs.commissionReport for fs in ib.fills()])[["execId", "realizedPNL"]].set_index("execId")

# %%
# strategy parameters
sma_s = 2
sma_l = 5
freq = "1 min"
units = 1000
contract = Forex('EURUSD') 
ib.qualifyContracts(contract)
cfd = CFD("EUR", currency = "USD")
ib.qualifyContracts(cfd)
conID = cfd.conId

# %%
def onBarUpdate(bars, hasNewBar):  
    global df, last_bar
    
    if bars[-1].date > last_bar: 
        last_bar = bars[-1].date
    
        # Data Processing
        df = pd.DataFrame(bars)[["date", "open", "high", "low", "close"]].iloc[:-1] 
        df.set_index("date", inplace = True)
        
        ####################### Trading Strategy ###########################
        df = df[["close"]].copy()
        df["sma_s"] = df.close.rolling(sma_s).mean()
        df["sma_l"] = df.close.rolling(sma_l).mean()
        df.dropna(inplace = True)
        df["position"] = np.where(df["sma_s"] > df["sma_l"], 1, -1 )
        ####################################################################
        
        # Trading
        target = df["position"][-1] * units
        execute_trade(target = target)
        
        # Display
        clear_output(wait=True)
        display(df)
    else:
        try:
            trade_reporting()
        except:
            pass

def execute_trade(target):
    global current_pos
    
    # 1. get current Position
    try:
        current_pos = [pos.position for pos in ib.positions() if pos.contract.conId == conID][0]
    except:
        current_pos = 0
         
    # 2. identify required trades
    trades = target - current_pos
        
    # 3. trade execution
    if trades > 0:
        side = "BUY"
        order = MarketOrder(side, abs(trades))
        trade = ib.placeOrder(cfd, order)  
    elif trades < 0:
        side = "SELL"
        order = MarketOrder(side, abs(trades))
        trade = ib.placeOrder(cfd, order)
    else:
        pass

def trade_reporting():
    global report
    
    fill_df = util.df([fs.execution for fs in ib.fills()])[["execId", "time", "side", "cumQty", "avgPrice"]].set_index("execId")
    profit_df = util.df([fs.commissionReport for fs in ib.fills()])[["execId", "realizedPNL"]].set_index("execId")
    report = pd.concat([fill_df, profit_df], axis = 1).set_index("time").loc[session_start:]
    report = report.groupby("time").agg({"side":"first", "cumQty":"max", "avgPrice":"mean", "realizedPNL":"sum"})
    report["cumPNL"] = report.realizedPNL.cumsum()
        
    clear_output(wait=True)
    display(df, report)

# %%
# session_start = pd.to_datetime(dt.datetime.utcnow()).tz_localize("utc") # old
session_start = pd.to_datetime(datetime.now(timezone.utc))# new 
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='1 D',
        barSizeSetting=freq,
        whatToShow='MIDPOINT',
        useRTH=True,
        formatDate=2,
        keepUpToDate=True)
last_bar = bars[-1].date
bars.updateEvent += onBarUpdate
ib.sleep(120) # new - to be added

# %%
df # still getting updated until you cancel. Trading continues until you cancel!!!

# %%
report # still getting updated until you cancel. Trading continues until you cancel!!!

# %%
ib.cancelHistoricalData(bars) # cancel trading

# %%
ib.disconnect()

# %% [markdown]
# ## Stop the Trading Session

# %% [markdown]
# Potential Triggers:
# - stop at a certain time (e.g. 21:59 UTC time)
# - stop once a certain profit/loss limit has been reached
# - etc.

# %% [markdown]
# Required Actions:
# - Stop Stream/Session
# - Close Open Position (go neutral)

# %%
from ib_async import * 
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, timezone # new
from IPython.display import display, clear_output
util.startLoop()

# %%
ib = IB()
ib.connect()

# %%
# strategy parameters
sma_s = 2
sma_l = 5
freq = "1 min"
units = 1000
end_time = dt.time(11, 5, 0) # stop condition
contract = Forex('EURUSD') 
ib.qualifyContracts(contract)
cfd = CFD("EUR", currency = "USD")
ib.qualifyContracts(cfd)
conID = cfd.conId

# %%
# dt.datetime.utcnow().time() #old

# %%
datetime.now(timezone.utc).time() # new

# %%
datetime.now(timezone.utc).time() >= end_time # new

# %%
def onBarUpdate(bars, hasNewBar):  
    global df, last_bar
    
    if bars[-1].date > last_bar: 
        last_bar = bars[-1].date
    
        # Data Processing
        df = pd.DataFrame(bars)[["date", "open", "high", "low", "close"]].iloc[:-1] 
        df.set_index("date", inplace = True)
        
        ####################### Trading Strategy ###########################
        df = df[["close"]].copy()
        df["sma_s"] = df.close.rolling(sma_s).mean()
        df["sma_l"] = df.close.rolling(sma_l).mean()
        df.dropna(inplace = True)
        df["position"] = np.where(df["sma_s"] > df["sma_l"], 1, -1 )
        ####################################################################
        
        # Trading
        target = df["position"][-1] * units
        execute_trade(target = target)
        
        # Display
        clear_output(wait=True)
        display(df)
    else:
        try:
            trade_reporting()
        except:
            pass

def execute_trade(target):
    global current_pos
    
    # 1. get current Position
    try:
        current_pos = [pos.position for pos in ib.positions() if pos.contract.conId == conID][0]
    except:
        current_pos = 0
         
    # 2. identify required trades
    trades = target - current_pos
        
    # 3. trade execution
    if trades > 0:
        side = "BUY"
        order = MarketOrder(side, abs(trades))
        trade = ib.placeOrder(cfd, order)  
    elif trades < 0:
        side = "SELL"
        order = MarketOrder(side, abs(trades))
        trade = ib.placeOrder(cfd, order)
    else:
        pass

def trade_reporting():
    global report
    
    fill_df = util.df([fs.execution for fs in ib.fills()])[["execId", "time", "side", "cumQty", "avgPrice"]].set_index("execId")
    profit_df = util.df([fs.commissionReport for fs in ib.fills()])[["execId", "realizedPNL"]].set_index("execId")
    report = pd.concat([fill_df, profit_df], axis = 1).set_index("time").loc[session_start:]
    report = report.groupby("time").agg({"side":"first", "cumQty":"max", "avgPrice":"mean", "realizedPNL":"sum"})
    report["cumPNL"] = report.realizedPNL.cumsum()
        
    clear_output(wait=True)
    display(df, report)

# %%
# start trading session
session_start = pd.to_datetime(datetime.now(timezone.utc))# new
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='1 D',
        barSizeSetting=freq,
        whatToShow='MIDPOINT',
        useRTH=True,
        formatDate=2,
        keepUpToDate=True)
last_bar = bars[-1].date
bars.updateEvent += onBarUpdate
ib.sleep(30) # new - to be added (optional)

# stop trading session
while True:
    ib.sleep(5) # check every 5 seconds
    if datetime.now(timezone.utc).time() >= end_time: # if stop conditions has been met
        execute_trade(target = 0) # close open position 
        ib.cancelHistoricalData(bars) # stop stream
        ib.sleep(10)
        try:
            trade_reporting() # final reporting
        except:
            pass
        print("Session Stopped.")
        ib.disconnect()
        break
    else:
        pass

# %% [markdown]
# ## Trading other Strategies - Coding Challenge

# %%
from ib_async import * 
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, timezone # new
from IPython.display import display, clear_output
util.startLoop()

# %%
ib = IB()
ib.connect()

# %% [markdown]
# __Strategy 1__: Simple Contrarian Strategy (1min / window = 1)

# %% [markdown]
# ## Stop here if you don´t want to see the solution!

# %% [markdown]
# ###############################################################

# %%
# strategy parameters
freq = "1 min"
window = 1
units = 1000
end_time = dt.time(21, 59, 0) # stop condition
contract = Forex('EURUSD') 
ib.qualifyContracts(contract)
cfd = CFD("EUR", currency = "USD")
ib.qualifyContracts(cfd)
conID = cfd.conId

# %%
def onBarUpdate(bars, hasNewBar):  
    global df, last_bar
    
    if bars[-1].date > last_bar: 
        last_bar = bars[-1].date
    
        # Data Processing
        df = pd.DataFrame(bars)[["date", "open", "high", "low", "close"]].iloc[:-1] 
        df.set_index("date", inplace = True)
        
        ####################### Trading Strategy ###########################
        df = df[["close"]].copy()
        df["returns"] = np.log(df["close"] / df["close"].shift())
        df["position"] = -np.sign(df.returns.rolling(window).mean())
        ####################################################################
        
        # Trading
        target = df["position"][-1] * units
        execute_trade(target = target)
        
        # Display
        clear_output(wait=True)
        display(df)
    else:
        try:
            trade_reporting()
        except:
            pass

def execute_trade(target):
    global current_pos
    
    # 1. get current Position
    try:
        current_pos = [pos.position for pos in ib.positions() if pos.contract.conId == conID][0]
    except:
        current_pos = 0
         
    # 2. identify required trades
    trades = target - current_pos
        
    # 3. trade execution
    if trades > 0:
        side = "BUY"
        order = MarketOrder(side, abs(trades))
        trade = ib.placeOrder(cfd, order)  
    elif trades < 0:
        side = "SELL"
        order = MarketOrder(side, abs(trades))
        trade = ib.placeOrder(cfd, order)
    else:
        pass

def trade_reporting():
    global report
    
    fill_df = util.df([fs.execution for fs in ib.fills()])[["execId", "time", "side", "cumQty", "avgPrice"]].set_index("execId")
    profit_df = util.df([fs.commissionReport for fs in ib.fills()])[["execId", "realizedPNL"]].set_index("execId")
    report = pd.concat([fill_df, profit_df], axis = 1).set_index("time").loc[session_start:]
    report = report.groupby("time").agg({"side":"first", "cumQty":"max", "avgPrice":"mean", "realizedPNL":"sum"})
    report["cumPNL"] = report.realizedPNL.cumsum()
        
    clear_output(wait=True)
    display(df, report)

# %%
# start trading session
session_start = pd.to_datetime(datetime.now(timezone.utc))# new
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='1 D',
        barSizeSetting=freq,
        whatToShow='MIDPOINT',
        useRTH=True,
        formatDate=2,
        keepUpToDate=True)
last_bar = bars[-1].date
bars.updateEvent += onBarUpdate
ib.sleep(30) # new - to be added (optional)

# stop trading session
while True:
    ib.sleep(5) # check every 5 seconds
    if datetime.now(timezone.utc).time() >= end_time: # if stop conditions has been met
        execute_trade(target = 0) # close open position 
        ib.cancelHistoricalData(bars) # stop stream
        ib.sleep(10)
        try:
            trade_reporting() # final reporting
        except:
            pass
        print("Session Stopped.")
        ib.disconnect()
        break
    else:
        pass

# %% [markdown]
# __Strategy 2__: Bollinger Bands SMA 20 (minutes) / 1 Standard Deviation

# %% [markdown]
# ## Stop here if you don´t want to see the solution!

# %% [markdown]
# ###############################################################

# %%
from ib_async import * 
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime, timezone # new
from IPython.display import display, clear_output
util.startLoop()

# %%
ib = IB()
ib.connect()

# %%
# strategy parameters
freq = "1 min"
sma = 20
dev = 1
units = 1000
end_time = dt.time(21, 59, 0) # stop condition
contract = Forex('EURUSD') 
ib.qualifyContracts(contract)
cfd = CFD("EUR", currency = "USD")
ib.qualifyContracts(cfd)
conID = cfd.conId

# %%
def onBarUpdate(bars, hasNewBar):  
    global df, last_bar
    
    if bars[-1].date > last_bar: 
        last_bar = bars[-1].date
    
        # Data Processing
        df = pd.DataFrame(bars)[["date", "open", "high", "low", "close"]].iloc[:-1] 
        df.set_index("date", inplace = True)
        
        ####################### Trading Strategy ###########################
        df = df[["close"]].copy()
        df["SMA"] = df["close"].rolling(sma).mean()
        df["Lower"] = df["SMA"] - df["close"].rolling(sma).std() * dev
        df["Upper"] = df["SMA"] + df["close"].rolling(sma).std() * dev
        df["distance"] = df["close"] - df.SMA
        df["position"] = np.where(df["close"] < df.Lower, 1, np.nan)
        df["position"] = np.where(df["close"] > df.Upper, -1, df["position"])
        df["position"] = np.where(df.distance * df.distance.shift(1) < 0, 0, df["position"])
        df["position"] = df.position.ffill().fillna(0)
        ####################################################################
        
        # Trading
        target = df["position"][-1] * units
        execute_trade(target = target)
        
        # Display
        clear_output(wait=True)
        display(df)
    else:
        try:
            trade_reporting()
        except:
            pass

def execute_trade(target):
    global current_pos
    
    # 1. get current Position
    try:
        current_pos = [pos.position for pos in ib.positions() if pos.contract.conId == conID][0]
    except:
        current_pos = 0
         
    # 2. identify required trades
    trades = target - current_pos
        
    # 3. trade execution
    if trades > 0:
        side = "BUY"
        order = MarketOrder(side, abs(trades))
        trade = ib.placeOrder(cfd, order)  
    elif trades < 0:
        side = "SELL"
        order = MarketOrder(side, abs(trades))
        trade = ib.placeOrder(cfd, order)
    else:
        pass

def trade_reporting():
    global report
    
    fill_df = util.df([fs.execution for fs in ib.fills()])[["execId", "time", "side", "cumQty", "avgPrice"]].set_index("execId")
    profit_df = util.df([fs.commissionReport for fs in ib.fills()])[["execId", "realizedPNL"]].set_index("execId")
    report = pd.concat([fill_df, profit_df], axis = 1).set_index("time").loc[session_start:]
    report = report.groupby("time").agg({"side":"first", "cumQty":"max", "avgPrice":"mean", "realizedPNL":"sum"})
    report["cumPNL"] = report.realizedPNL.cumsum()
        
    clear_output(wait=True)
    display(df, report)

# %%
# start trading session
session_start = pd.to_datetime(datetime.now(timezone.utc))# new
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='1 D',
        barSizeSetting=freq,
        whatToShow='MIDPOINT',
        useRTH=True,
        formatDate=2,
        keepUpToDate=True)
last_bar = bars[-1].date
bars.updateEvent += onBarUpdate
ib.sleep(30) # new - to be added (optional)

# stop trading session
while True:
    ib.sleep(5) # check every 5 seconds
    if datetime.now(timezone.utc).time() >= end_time: # if stop conditions has been met
        execute_trade(target = 0) # close open position 
        ib.cancelHistoricalData(bars) # stop stream
        ib.sleep(10)
        try:
            trade_reporting() # final reporting
        except:
            pass
        print("Session Stopped.")
        ib.disconnect()
        break
    else:
        pass

# %% [markdown]
# ## Machine Learning Strategies (1) - Model Fitting

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier # added (from sklearn v. 1.7)

# %%
data = pd.read_csv("five_minute.csv", parse_dates = ["time"], index_col = "time")
data

# %%
data["returns"] = np.log(data.div(data.shift(1)))

# %%
data.dropna(inplace = True)

# %%
data["direction"] = np.sign(data.returns)
data

# %%
lags = 2

# %%
cols = []
for lag in range(1, lags + 1):
    col = "lag{}".format(lag)
    data[col] = data.returns.shift(lag)
    cols.append(col)
data.dropna(inplace = True)

# %% [markdown]
# ++++++++++++++++++++++++++++

# %% [markdown]
# __Scaling/Standardizing Features (new)__

# %%
means = data[cols].mean()
means

# %%
stand_devs = data[cols].std()
stand_devs

# %%
data[cols] = (data[cols]-means) / stand_devs
data

# %% [markdown]
# +++++++++++++++++++++++++++

# %%
lm = OneVsRestClassifier(LogisticRegression(C = 1e6, max_iter = 100000)) # new (from sklearn v. 1.7)

# %%
lm.fit(data[cols], data.direction)
lm

# %% [markdown]
# __In-Sample "Prediction"__

# %%
data["pred"] = lm.predict(data[cols])
data

# %%
hits = np.sign(data.direction * data.pred).value_counts()
hits

# %%
hit_ratio = hits[1.0] / sum(hits)
hit_ratio

# %% [markdown]
# __Saving the model__

# %%
lm

# %%
import pickle

# %%
pickle.dump(lm, open("logreg.pkl", "wb"))

# %% [markdown]
# __Saving the parameters (mean, std)__ NEW

# %%
params = {"mu":means, "std":stand_devs}
params

# %%
pickle.dump(params, open("params.pkl", "wb"))

# %% [markdown]
# ## Machine Learning Strategies (2) - Implementation

# %%
from ib_async import * 
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
import pickle
import datetime as dt
from datetime import datetime, timezone # new
from IPython.display import display, clear_output
util.startLoop()

# %%
ib = IB()
ib.connect()

# %%
# strategy parameters
freq = "5 mins"
lm = pickle.load(open("logreg.pkl", "rb"))
lags = 2
params = pickle.load(open("params.pkl", "rb"))
means = params["mu"]
stand_devs = params["std"]
units = 1000
end_time = dt.time(21, 59, 0) # stop condition
contract = Forex('EURUSD') 
ib.qualifyContracts(contract)
cfd = CFD("EUR", currency = "USD")
ib.qualifyContracts(cfd)
conID = cfd.conId

# %%
lm

# %%
def onBarUpdate(bars, hasNewBar):  
    global df, last_bar
    
    if bars[-1].date > last_bar: 
        last_bar = bars[-1].date
    
        # Data Processing
        df = pd.DataFrame(bars)[["date", "open", "high", "low", "close"]]#.iloc[:-1] keep latest incomplete bar
        df.set_index("date", inplace = True)
        
        ####################### Trading Strategy ###########################
        df = df[["close"]].copy()
        df["returns"] = np.log(df["close"] / df["close"].shift())

        cols = []
        for lag in range(1, lags + 1):
            col = "lag{}".format(lag)
            df[col] = df.returns.shift(lag)
            cols.append(col)
        df.dropna(inplace = True)
        df[cols] = (df[cols] - means) / stand_devs
        
        df["position"] = lm.predict(df[cols])
        ####################################################################
        
        # Trading
        target = df["position"][-1] * units
        execute_trade(target = target)
        
        # Display
        clear_output(wait=True)
        display(df)
    else:
        try:
            trade_reporting()
        except:
            pass

def execute_trade(target):
    global current_pos
    
    # 1. get current Position
    try:
        current_pos = [pos.position for pos in ib.positions() if pos.contract.conId == conID][0]
    except:
        current_pos = 0
         
    # 2. identify required trades
    trades = target - current_pos
        
    # 3. trade execution
    if trades > 0:
        side = "BUY"
        order = MarketOrder(side, abs(trades))
        trade = ib.placeOrder(cfd, order)  
    elif trades < 0:
        side = "SELL"
        order = MarketOrder(side, abs(trades))
        trade = ib.placeOrder(cfd, order)
    else:
        pass

def trade_reporting():
    global report
    
    fill_df = util.df([fs.execution for fs in ib.fills()])[["execId", "time", "side", "cumQty", "avgPrice"]].set_index("execId")
    profit_df = util.df([fs.commissionReport for fs in ib.fills()])[["execId", "realizedPNL"]].set_index("execId")
    report = pd.concat([fill_df, profit_df], axis = 1).set_index("time").loc[session_start:]
    report = report.groupby("time").agg({"side":"first", "cumQty":"max", "avgPrice":"mean", "realizedPNL":"sum"})
    report["cumPNL"] = report.realizedPNL.cumsum()
        
    clear_output(wait=True)
    display(df, report)

# %%
# start trading session
session_start = pd.to_datetime(datetime.now(timezone.utc))# new
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='1 D',
        barSizeSetting=freq,
        whatToShow='MIDPOINT',
        useRTH=True,
        formatDate=2,
        keepUpToDate=True)
last_bar = bars[-1].date
bars.updateEvent += onBarUpdate
ib.sleep(30) # new - to be added (optional)

# stop trading session
while True:
    ib.sleep(5) # check every 5 seconds
    if datetime.now(timezone.utc).time() >= end_time: # if stop conditions has been met
        execute_trade(target = 0) # close open position 
        ib.cancelHistoricalData(bars) # stop stream
        ib.sleep(10)
        try:
            trade_reporting() # final reporting
        except:
            pass
        print("Session Stopped.")
        ib.disconnect()
        break
    else:
        pass
